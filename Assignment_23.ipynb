# %% [markdown]
# <b>1. What is the result of the code, and why?
# &gt;&gt;&gt; def func(a, b=6, c=8):
# print(a, b, c)
# &gt;&gt;&gt; func(1, 2)

# %% [markdown]
# 1 2 8<br>As c has a default argument, not passing 3 arguments will not raise an exception. As we passed positional arguments a takes 1 and the default argument of b is overriden by 2

# %% [markdown]
# <b>2. What is the result of this code, and why?
# &gt;&gt;&gt; def func(a, b, c=5):
# print(a, b, c)
# &gt;&gt;&gt; func(1, c=3, b=2)

# %% [markdown]
# 1 2 3<br>We passed positional argument 1 hence, a becomes 1. Keyword arguments c=3 and b=2 are assigned to c and b

# %% [markdown]
# <b>3. How about this code: what is its result, and why?
# &gt;&gt;&gt; def func(a, *pargs):
# print(a, pargs)
# &gt;&gt;&gt; func(1, 2, 3)

# %% [markdown]
# 1 (2, 3)<br>Positional argeument 1 is assigned to a. *pargs takes the other 2 arguments and returns them as a tuple

# %% [markdown]
# <b>4. What does this code print, and why?
# &gt;&gt;&gt; def func(a, **kargs):
# print(a, kargs)
# &gt;&gt;&gt; func(a=1, c=3, b=2)

# %% [markdown]
# 1 {'c': 3, 'b': 2}<br>Positional argument 1 is passed to a. \*\*kargs takes the other 2 arguments and returns them as a dictionary

# %% [markdown]
# <b>5. What gets printed by this, and explain?
# &gt;&gt;&gt; def func(a, b, c=8, d=5): print(a, b, c, d)
# &gt;&gt;&gt; func(1, *(5, 6))

# %% [markdown]
# 1 5 6 5<br>\*(5,6) unpacks the tuple and assigns 5 to b and 6 to c. Positional argument 1 is passed to a and defualt argument of d i.e. 5 is passed to d

# %% [markdown]
# <b>6. what is the result of this, and explain?
# &gt;&gt;&gt; def func(a, b, c): a = 2; b[0] = &#39;x&#39;; c[&#39;a&#39;] = &#39;y&#39;
# &gt;&gt;&gt; l=1; m=[1]; n={&#39;a&#39;:0}
# &gt;&gt;&gt; func(l, m, n)
#
# &gt;&gt;&gt; l, m, n

# %% [markdown]
# (1, ['x'], {'a': 'y'})<br>As we haven't passed a copy of list and dictionary to the function, the same address is passed in the argument and elements in the respective addresses are modeified. Since, this doesn't happen with primitive data types (like int, str, etc), l is still 1. We need to pass copy() of list and dictionary to prevent from being mutated.
